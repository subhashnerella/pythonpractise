# %%
import numpy
import math
from matplotlib import pyplot
import cmath

# %%
x = numpy.linspace(-1.2,1.2,20)

# %%
x = x -.2

# %%
print x
# Out:
# [-1.4        -1.27368421 -1.14736842 -1.02105263 -0.89473684 -0.76842105
#  -0.64210526 -0.51578947 -0.38947368 -0.26315789 -0.13684211 -0.01052632
#   0.11578947  0.24210526  0.36842105  0.49473684  0.62105263  0.74736842
#   0.87368421  1.        ]

# %%
y = (1.2**2 - (x+0.2)**2)**0.5

# %%
print y
# Out:
# [ 0.          0.53591251  0.73654129  0.87514146  0.9784379   1.05683372
#   1.11559085  1.15770333  1.18494714  1.1983368   1.1983368   1.18494714
#   1.15770333  1.11559085  1.05683372  0.9784379   0.87514146  0.73654129
#   0.53591251  0.        ]

# %%
print x
# Out:
# [-1.4        -1.27368421 -1.14736842 -1.02105263 -0.89473684 -0.76842105
#  -0.64210526 -0.51578947 -0.38947368 -0.26315789 -0.13684211 -0.01052632
#   0.11578947  0.24210526  0.36842105  0.49473684  0.62105263  0.74736842
#   0.87368421  1.        ]

# %%
z=numpy.vectorize(complex)(x,y)

# %%
v = numpy.vectorize(complex)(x,-y)

# %%
print z
# Out:
# [-1.40000000+0.j         -1.27368421+0.53591251j -1.14736842+0.73654129j
#  -1.02105263+0.87514146j -0.89473684+0.9784379j  -0.76842105+1.05683372j
#  -0.64210526+1.11559085j -0.51578947+1.15770333j -0.38947368+1.18494714j
#  -0.26315789+1.1983368j  -0.13684211+1.1983368j  -0.01052632+1.18494714j
#   0.11578947+1.15770333j  0.24210526+1.11559085j  0.36842105+1.05683372j
#   0.49473684+0.9784379j   0.62105263+0.87514146j  0.74736842+0.73654129j
#   0.87368421+0.53591251j  1.00000000+0.j        ]

# %%
def get_joukouskipoints(z):
    q =z+1/z
    return q

# %%
w = get_joukouskipoints(z)
n = get_joukouskipoints(v)

# %%
print w
# Out:
# [-2.11428571+0.j         -1.94071839+0.2552527j  -1.76458246+0.34032712j
#  -1.58566264+0.39121574j -1.40371888+0.42184149j -1.21848270+0.43784973j
#  -1.02965291+0.44226727j -0.83689039+0.4369837j  -0.63981198+0.42330994j
#  -0.43798307+0.40223893j -0.23090868+0.37458864j -0.01802257+0.34109423j
#   0.20132602+0.30247925j  0.42788878+0.25952356j  0.66253870+0.21314293j
#   0.90629551+0.16450094j  1.16035793+0.11519229j  1.42614471+0.06759844j
#   1.70534754+0.02577535j  2.00000000+0.j        ]

# %%
numpy.shape(w)
# Out:
# (20,)

# %%
# %matplotlib inline
pyplot.plot(w.real,w.imag)
pyplot.plot(n.real,n.imag)
pyplot.show()

# %%
R = 1.15
r = numpy.linspace(R,5,100)

# %%
print r
# Out:
# [ 1.15        1.18888889  1.22777778  1.26666667  1.30555556  1.34444444
#   1.38333333  1.42222222  1.46111111  1.5         1.53888889  1.57777778
#   1.61666667  1.65555556  1.69444444  1.73333333  1.77222222  1.81111111
#   1.85        1.88888889  1.92777778  1.96666667  2.00555556  2.04444444
#   2.08333333  2.12222222  2.16111111  2.2         2.23888889  2.27777778
#   2.31666667  2.35555556  2.39444444  2.43333333  2.47222222  2.51111111
#   2.55        2.58888889  2.62777778  2.66666667  2.70555556  2.74444444
#   2.78333333  2.82222222  2.86111111  2.9         2.93888889  2.97777778
#   3.01666667  3.05555556  3.09444444  3.13333333  3.17222222  3.21111111
#   3.25        3.28888889  3.32777778  3.36666667  3.40555556  3.44444444
#   3.48333333  3.52222222  3.56111111  3.6         3.63888889  3.67777778
#   3.71666667  3.75555556  3.79444444  3.83333333  3.87222222  3.91111111
#   3.95        3.98888889  4.02777778  4.06666667  4.10555556  4.14444444
#   4.18333333  4.22222222  4.26111111  4.3         4.33888889  4.37777778
#   4.41666667  4.45555556  4.49444444  4.53333333  4.57222222  4.61111111
#   4.65        4.68888889  4.72777778  4.76666667  4.80555556  4.84444444
#   4.88333333  4.92222222  4.96111111  5.        ]

# %%
theta = numpy.linspace(0,2*numpy.pi,145)

# %%
print theta
# Out:
# [ 0.          0.04363323  0.08726646  0.13089969  0.17453293  0.21816616
#   0.26179939  0.30543262  0.34906585  0.39269908  0.43633231  0.47996554
#   0.52359878  0.56723201  0.61086524  0.65449847  0.6981317   0.74176493
#   0.78539816  0.82903139  0.87266463  0.91629786  0.95993109  1.00356432
#   1.04719755  1.09083078  1.13446401  1.17809725  1.22173048  1.26536371
#   1.30899694  1.35263017  1.3962634   1.43989663  1.48352986  1.5271631
#   1.57079633  1.61442956  1.65806279  1.70169602  1.74532925  1.78896248
#   1.83259571  1.87622895  1.91986218  1.96349541  2.00712864  2.05076187
#   2.0943951   2.13802833  2.18166156  2.2252948   2.26892803  2.31256126
#   2.35619449  2.39982772  2.44346095  2.48709418  2.53072742  2.57436065
#   2.61799388  2.66162711  2.70526034  2.74889357  2.7925268   2.83616003
#   2.87979327  2.9234265   2.96705973  3.01069296  3.05432619  3.09795942
#   3.14159265  3.18522588  3.22885912  3.27249235  3.31612558  3.35975881
#   3.40339204  3.44702527  3.4906585   3.53429174  3.57792497  3.6215582
#   3.66519143  3.70882466  3.75245789  3.79609112  3.83972435  3.88335759
#   3.92699082  3.97062405  4.01425728  4.05789051  4.10152374  4.14515697
#   4.1887902   4.23242344  4.27605667  4.3196899   4.36332313  4.40695636
#   4.45058959  4.49422282  4.53785606  4.58148929  4.62512252  4.66875575
#   4.71238898  4.75602221  4.79965544  4.84328867  4.88692191  4.93055514
#   4.97418837  5.0178216   5.06145483  5.10508806  5.14872129  5.19235452
#   5.23598776  5.27962099  5.32325422  5.36688745  5.41052068  5.45415391
#   5.49778714  5.54142038  5.58505361  5.62868684  5.67232007  5.7159533
#   5.75958653  5.80321976  5.84685299  5.89048623  5.93411946  5.97775269
#   6.02138592  6.06501915  6.10865238  6.15228561  6.19591884  6.23955208
#   6.28318531]

# %%
radius_matrix, theta_matrix = numpy.meshgrid(r,theta)

# %%
X = (radius_matrix * numpy.cos(theta_matrix)-0.15)
Y = radius_matrix * numpy.sin(theta_matrix)

# %%
print X
# Out:
# [[ 1.          1.03888889  1.07777778 ...,  4.77222222  4.81111111  4.85      ]
#  [ 0.99890545  1.03775733  1.07660921 ...,  4.76753736  4.80638923
#    4.84524111]
#  [ 0.9956239   1.03436481  1.07310571 ...,  4.75349168  4.79223259
#    4.83097349]
#  ...,
#  [ 0.9956239   1.03436481  1.07310571 ...,  4.75349168  4.79223259
#    4.83097349]
#  [ 0.99890545  1.03775733  1.07660921 ...,  4.76753736  4.80638923
#    4.84524111]
#  [ 1.          1.03888889  1.07777778 ...,  4.77222222  4.81111111  4.85      ]]

# %%
# %matplotlib inline
pyplot.figure(figsize=(10,10))
pyplot.scatter(X,Y,color='#CD2305', s=0.25, marker='o')

# %%
z=numpy.vectorize(complex)(X,Y)

# %% [raw]
# def get_joukouskitrnsform(X,Y):
#     q =(X+Y)+1/(X+Y)
#     return q

# %%
w=get_joukouskipoints(z)

# %%
# %matplotlib inline
pyplot.figure(figsize=(10,10))
pyplot.xlim(-6,6)
pyplot.ylim(-6,6)
pyplot.scatter(w.real,w.imag,color='#CD2305', s=0.25, marker='o')

# %%
kappa = 8.309                        # strength of the doublet
x_doublet, y_doublet = -0.15, 0.0

# %%
def get_velocity_doublet(strength, xd, yd, X, Y):
    """Returns the velocity field generated by a doublet.
    
    Arguments
    ---------
    strength -- strength of the doublet.
    xd, yd -- coordinates of the doublet.
    X, Y -- mesh grid.
    """
    u = - strength/(2*math.pi)*((X-xd)**2-(Y-yd)**2)/((X-xd)**2+(Y-yd)**2)**2
    v = - strength/(2*math.pi)*2*(X-xd)*(Y-yd)/((X-xd)**2+(Y-yd)**2)**2
    
    return u, v

# %%
u_doublet, v_doublet = get_velocity_doublet(kappa, x_doublet, y_doublet, X, Y)

# %%
u_doublet = u_doublet + 1.0

# %%
print u_doublet
# Out:
# [[  6.16845742e-05   6.44083134e-02   1.22737928e-01 ...,   9.45418376e-01
#     9.46270725e-01   9.47103263e-01]
#  [  3.86675175e-03   6.79685223e-02   1.26076175e-01 ...,   9.45626075e-01
#     9.46475181e-01   9.47304551e-01]
#  [  1.52529944e-02   7.86220534e-02   1.36065510e-01 ...,   9.46247593e-01
#     9.47086993e-01   9.47906883e-01]
#  ...,
#  [  1.52529944e-02   7.86220534e-02   1.36065510e-01 ...,   9.46247593e-01
#     9.47086993e-01   9.47906883e-01]
#  [  3.86675175e-03   6.79685223e-02   1.26076175e-01 ...,   9.45626075e-01
#     9.46475181e-01   9.47304551e-01]
#  [  6.16845742e-05   6.44083134e-02   1.22737928e-01 ...,   9.45418376e-01
#     9.46270725e-01   9.47103263e-01]]

# %% [raw]
# u_inf = 1.0
# u_freestream = u_inf * numpy.ones((N, N), dtype=float)
# v_freestream = numpy.zeros((N, N), dtype=float)
# u_t = u_freestream + u_doublet
# v_t = v_freestream + v_doublet

# %%
# %matplotlib inline

# plots the streamlines
size = 10
pyplot.figure(figsize=(size, size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(-6, 6)
pyplot.ylim(-6, 6)
pyplot.streamplot(X, Y, u_doublet, v_doublet,density=0.5, linewidth=0.5, arrowsize=0.5, arrowstyle='->')
pyplot.scatter(x_doublet, y_doublet, color='#CD2305', s=80, marker='o');
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-48-9dd51714e539> in <module>()
#       8 pyplot.xlim(-6, 6)
#       9 pyplot.ylim(-6, 6)
# ---> 10 pyplot.streamplot(X, Y, u_doublet, v_doublet,density=0.5, linewidth=0.5, arrowsize=0.5, arrowstyle='->')
#      11 pyplot.scatter(x_doublet, y_doublet, color='#CD2305', s=80, marker='o');
#
# C:\Users\subhash nerella\Anaconda\lib\site-packages\matplotlib\pyplot.pyc in streamplot(x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, hold)
#    3331                             arrowsize=arrowsize, arrowstyle=arrowstyle,
#    3332                             minlength=minlength, transform=transform,
# -> 3333                             zorder=zorder)
#    3334         draw_if_interactive()
#    3335     finally:
#
# C:\Users\subhash nerella\Anaconda\lib\site-packages\matplotlib\axes\_axes.pyc in streamplot(self, x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder)
#    4188                                               minlength=minlength,
#    4189                                               transform=transform,
# -> 4190                                               zorder=zorder)
#    4191         return stream_container
#    4192     streamplot.__doc__ = mstream.streamplot.__doc__
#
# C:\Users\subhash nerella\Anaconda\lib\site-packages\matplotlib\streamplot.pyc in streamplot(axes, x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder)
#      72
#      73     """
# ---> 74     grid = Grid(x, y)
#      75     mask = StreamMask(density)
#      76     dmap = DomainMap(grid, mask)
#
# C:\Users\subhash nerella\Anaconda\lib\site-packages\matplotlib\streamplot.pyc in __init__(self, x, y)
#     259         if len(x.shape) == 2:
#     260             x_row = x[0]
# --> 261             assert np.allclose(x_row, x)
#     262             x = x_row
#     263         else:
#
# AssertionError:
